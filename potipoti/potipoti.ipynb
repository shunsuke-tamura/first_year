# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from time import sleep
import pygame

def sound():
    pygame.mixer.init() #初期化
    pygame.mixer.music.load('alerm1.mp3') #読み込み
    pygame.mixer.music.play(-1) #ループ再生（引数を1にすると1回のみ再生）
    input()
    pygame.mixer.music.stop()
    
    
def poti():
    a = 0
    while(1):
        try:
            a = a + 1
            '''
            driver.switch_to.window(driver.window_handles[-1])
            wed1_btn = driver.find_element_by_xpath("/html/body/table[4]/tbody/tr/td/table/tbody/tr[2]/td[4]/input")
            wed1_btn.click()
            driver.switch_to.window(driver.window_handles[-1])
            serch_btn = driver.find_element_by_xpath("/html/body/form/table[2]/tbody/tr/td/input")
            serch_btn.click()
            select_btn = driver.find_element_by_xpath("/html/body/form/table[4]/tbody/tr/td/table/tbody/tr[11]/td[1]/a/input")
            select_btn.click()
            sleep(1)
            enter_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[2]/input")
            enter_btn.click()
            sleep(1)
            close_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[1]/img")
            close_btn.click()
            '''
            
            '''
            driver.switch_to.window(driver.window_handles[-1])
            wed2_btn = driver.find_element_by_xpath("/html/body/table[4]/tbody/tr/td/table/tbody/tr[3]/td[4]/input")
            wed2_btn.click()
            driver.switch_to.window(driver.window_handles[-1])
            serch_btn = driver.find_element_by_xpath("/html/body/form/table[2]/tbody/tr/td/input")
            serch_btn.click()
            select_btn = driver.find_element_by_xpath("/html/body/form/table[4]/tbody/tr/td/table/tbody/tr[3]/td[1]/a/input")
            select_btn.click()
            sleep(1)
            enter_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[2]/input")
            enter_btn.click()
            sleep(1)
            close_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[1]/img")
            close_btn.click()
            '''
            
            driver.switch_to.window(driver.window_handles[-1])
            thr1_btn = driver.find_element_by_xpath("/html/body/table[4]/tbody/tr/td/table/tbody/tr[2]/td[5]/input")
            thr1_btn.click()
            driver.switch_to.window(driver.window_handles[-1])
            serch_btn = driver.find_element_by_xpath("/html/body/form/table[2]/tbody/tr/td/input")
            serch_btn.click()
            select_btn = driver.find_element_by_xpath("/html/body/form/table[4]/tbody/tr/td/table/tbody/tr[8]/td[1]/a/input")
            select_btn.click()
            sleep(1)
            enter_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[2]/input")
            enter_btn.click()
            sleep(1)
            close_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[1]/img")
            close_btn.click()
            
            '''
            driver.switch_to.window(driver.window_handles[-1])
            thr2_btn = driver.find_element_by_xpath("/html/body/table[4]/tbody/tr/td/table/tbody/tr[3]/td[5]/input")
            thr2_btn.click()
            driver.switch_to.window(driver.window_handles[-1])
            serch_btn = driver.find_element_by_xpath("/html/body/form/table[2]/tbody/tr/td/input")
            serch_btn.click()
            select_btn = driver.find_element_by_xpath("/html/body/form/table[4]/tbody/tr/td/table/tbody/tr[7]/td[1]/a/input")
            select_btn.click()
            sleep(1)
            enter_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[2]/input")
            enter_btn.click()
            sleep(1)
            close_btn = driver.find_element_by_xpath("/html/body/form/table[5]/tbody/tr/td[1]/img")
            close_btn.click()
            '''
            
            sleep(15)
            
            if a > 70:
                driver.switch_to.window(driver.window_handles[-1])
                back_btn = driver.find_element_by_xpath("/html/body/table[3]/tbody/tr/td[1]/table/tbody/tr/td/a")
                back_btn.click()
                re_btn = driver.find_element_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table/tbody/tr[2]/td/table/tbody/tr[3]/td[2]/a")
                re_btn.click()
                a = 0
    
        except Exception as e:
            print('type:' + str(type(e)))
            print('args:' + str(e.args))
            #print('message:' + e.message)
            print('e自身:' + str(e))
            sound()
            break
                
if __name__ == '__main__':
    driver = webdriver.Chrome("chromedriver.exe")
    driver.get('https://lc2.sc.admin.saga-u.ac.jp/kyoumu/rishuuInit.do;jsessionid=H2Ox4Kv-pFzSaAjo11YOuFTW.kmap2?mainMenuCode=002&parentMenuCode=001')
    sleep(5)
    poti()
    sleep(5)
    #driver.quit()
# Out:
# type:<class 'selenium.common.exceptions.NoSuchWindowException'>
# args:('no such window: window was already closed\n  (Session info: chrome=85.0.4183.121)', None, None)
# e自身:Message: no such window: window was already closed
#   (Session info: chrome=85.0.4183.121)
